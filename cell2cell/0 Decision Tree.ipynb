# %% [markdown]
# # **DecisionTree_Cell2Cell**

# %% [markdown]
# ## **Importing Libraries and Dataset**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, roc_auc_score, precision_recall_curve, average_precision_score

# %%
# Read the CSV dataset using pandas

data = pd.read_csv('preprocessed_data_cell2cell.csv')
data.info()

# Select the features and target variable

X_train = data.drop(columns=['Churn'])
y_train = data['Churn']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51046 entries, 0 to 51045
# Data columns (total 57 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Churn                      51046 non-null  int64
#  1   MonthlyRevenue             51046 non-null  float64
#  2   MonthlyMinutes             51046 non-null  float64
#  3   TotalRecurringCharge       51046 non-null  float64
#  4   DirectorAssistedCalls      51046 non-null  float64
#  5   OverageMinutes             51046 non-null  float64
#  6   RoamingCalls               51046 non-null  float64
#  7   PercChangeMinutes          51046 non-null  float64
#  8   PercChangeRevenues         51046 non-null  float64
#  9   DroppedCalls               51046 non-null  float64
#  10  BlockedCalls               51046 non-null  float64
#  11  UnansweredCalls            51046 non-null  float64
#  12  CustomerCareCalls          51046 non-null  float64
#  13  ThreewayCalls              51046 non-null  float64
#  14  ReceivedCalls              51046 non-null  float64
#  15  OutboundCalls              51046 non-null  float64
#  16  InboundCalls               51046 non-null  float64
#  17  PeakCallsInOut             51046 non-null  float64
#  18  OffPeakCallsInOut          51046 non-null  float64
#  19  DroppedBlockedCalls        51046 non-null  float64
#  20  CallForwardingCalls        51046 non-null  float64
#  21  CallWaitingCalls           51046 non-null  float64
#  22  MonthsInService            51046 non-null  int64
#  23  UniqueSubs                 51046 non-null  int64
#  24  ActiveSubs                 51046 non-null  int64
#  25  ServiceArea                51046 non-null  int64
#  26  Handsets                   51046 non-null  float64
#  27  HandsetModels              51046 non-null  float64
#  28  CurrentEquipmentDays       51046 non-null  float64
#  29  AgeHH1                     51046 non-null  float64
#  30  AgeHH2                     51046 non-null  float64
#  31  ChildrenInHH               51046 non-null  int64
#  32  HandsetRefurbished         51046 non-null  int64
#  33  HandsetWebCapable          51046 non-null  int64
#  34  TruckOwner                 51046 non-null  int64
#  35  RVOwner                    51046 non-null  int64
#  36  Homeownership              51046 non-null  int64
#  37  BuysViaMailOrder           51046 non-null  int64
#  38  RespondsToMailOffers       51046 non-null  int64
#  39  OptOutMailings             51046 non-null  int64
#  40  NonUSTravel                51046 non-null  int64
#  41  OwnsComputer               51046 non-null  int64
#  42  HasCreditCard              51046 non-null  int64
#  43  RetentionCalls             51046 non-null  int64
#  44  RetentionOffersAccepted    51046 non-null  int64
#  45  NewCellphoneUser           51046 non-null  int64
#  46  NotNewCellphoneUser        51046 non-null  int64
#  47  ReferralsMadeBySubscriber  51046 non-null  int64
#  48  IncomeGroup                51046 non-null  int64
#  49  OwnsMotorcycle             51046 non-null  int64
#  50  AdjustmentsToCreditRating  51046 non-null  int64
#  51  HandsetPrice               51046 non-null  int64
#  52  MadeCallToRetentionTeam    51046 non-null  int64
#  53  CreditRating               51046 non-null  int64
#  54  PrizmCode                  51046 non-null  int64
#  55  Occupation                 51046 non-null  int64
#  56  MaritalStatus              51046 non-null  int64
# dtypes: float64(26), int64(31)
# memory usage: 22.2 MB

# %% [markdown]
# ## **Model Training**

# %%
# Split the data into two sets: Training (70%), Test (30%)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

# Load the ML/DL model
clf = DecisionTreeClassifier()

# Fit the training set into the model
clf.fit(X_train, y_train)

# Predict the customer churn
y_train_pred = clf.predict(X_train)

# %% [markdown]
# ### **Classification Report**

# %%
# Calculate the accuracy of the model

accuracy_train = accuracy_score(y_train, y_train_pred)
print(f"Accuracy on training set: {accuracy_train * 100:.2f}%\n")

# Display the full classification report 

print(classification_report(y_train, y_train_pred))
# Out:
# Accuracy on training set: 100.00%
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     25459
#            1       1.00      1.00      1.00     10273
#
#     accuracy                           1.00     35732
#    macro avg       1.00      1.00      1.00     35732
# weighted avg       1.00      1.00      1.00     35732

# %% [markdown]
# ### **Confusion Matrix**

# %%
# Display the confusion matrix

conf_matrix_train = confusion_matrix(y_train, y_train_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues',
            xticklabels=clf.classes_, yticklabels=clf.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## **Model Enhancement**

# %%
# Tune the parameters of the model and find the best model using Grid Search

def tune_model(model, X_train, y_train, param_grid, scoring='accuracy', cv=5):   
    gridSearch = GridSearchCV(estimator=model, param_grid=param_grid,
                               scoring=scoring, cv=cv)
    
    gridSearch.fit(X_train, y_train)

    bestParameters = gridSearch.best_params_
    bestScore = gridSearch.best_score_

    print(f"Best parameters: {bestParameters}\n")
    print(f"Best {scoring} score: {bestScore}")
    
    bestModel = gridSearch.best_estimator_
    return bestModel

# Validate the model performance using cross validation method with num of folds = 5

def cross_validation(model, X_train, y_train, scoring='accuracy', cv=5):
    result = cross_val_score(model, X_train, y_train, scoring=scoring, cv=cv)

    print(f"\nCross Validation Scores ({scoring}): {result}")
    print(f"\nMean Accuracy      : {result.mean() * 100:.2f}%")
    print(f"Standard Deviation : {result.std():.2f}")

# %% [markdown]
# ### **Hyperparameter Tuning**

# %%
# Prepare the parameters of the model for tuning
clf_param = {
    'max_depth': np.arange(2, 15),
    'min_samples_split': [10, 20, 30, 40, 50, 100]}

# Assign the best model into a variable
clf_tuned = tune_model(clf, X_train, y_train, clf_param, 'accuracy', cv=5)

# Predict the customer churn using tuned model 
y_train_pred = clf_tuned.predict(X_train)
# Out:
# Best parameters: {'max_depth': 4, 'min_samples_split': 10}
#
# Best accuracy score: 0.7148773521041536

# %% [markdown]
# ### **Classification Report**

# %%
# Calculate the accuracy of the model

accuracy_train = accuracy_score(y_train, y_train_pred)
print(f"Accuracy on training set: {accuracy_train * 100:.2f}%\n")

# Display the full classification report 

print(classification_report(y_train, y_train_pred))
# Out:
# Accuracy on training set: 71.66%
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.99      0.83     25459
#            1       0.65      0.03      0.06     10273
#
#     accuracy                           0.72     35732
#    macro avg       0.68      0.51      0.45     35732
# weighted avg       0.70      0.72      0.61     35732

# %% [markdown]
# ### **Cross-Validation Score**

# %%
# Validate the model performance

cross_validation(clf_tuned, X_train, y_train, 'accuracy', 5)
# Out:
# Cross Validation Scores (accuracy): [0.71554498 0.71666433 0.71326616 0.71438567 0.71452561]
#
# Mean Accuracy      : 71.49%
# Standard Deviation : 0.00

# %% [markdown]
# ## **Model Testing and Evaluation**

# %%
# Predict the customer churn for test set using tuned model

y_test_pred = clf_tuned.predict(X_test)
y_test_pred_proba = clf_tuned.predict_proba(X_test)[:, 1]

# %% [markdown]
# ### **Classification Report**

# %%
# Calculate the accuracy of the model

accuracy_test = accuracy_score(y_test, y_test_pred)
print(f"Accuracy on test set: {accuracy_test * 100:.2f}%\n")

# Display the full classification report 

print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy on test set: 71.52%
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.99      0.83     10876
#            1       0.65      0.04      0.07      4438
#
#     accuracy                           0.72     15314
#    macro avg       0.68      0.51      0.45     15314
# weighted avg       0.70      0.72      0.61     15314

# %% [markdown]
# ### **Confusion Matrix**

# %%
# Display the confusion matrix

conf_matrix_test = confusion_matrix(y_test, y_test_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_test, annot=True, fmt='d', cmap='Blues',
            xticklabels=clf.classes_, yticklabels=clf.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### **Receiver Operating Characteristic (ROC) Curve**

# %%
# Calculate the FPR, TPR, and AUC score

fpr, tpr, _ = roc_curve(y_test, y_test_pred_proba)
auc_score = roc_auc_score(y_test, y_test_pred_proba)

# Plot the ROC Curve

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'Area Under Curve (AUC) = {auc_score:.2f})')
plt.fill_between(fpr, tpr, fpr, color='skyblue', alpha=0.4)
plt.plot([0, 1], [0, 1], color='skyblue', linestyle='--')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### **Precision-Recall Curve**

# %%
# Calculate the precision, recall, and average precision score

precision, recall, _ = precision_recall_curve(y_test, y_test_pred_proba)
avg_precision = average_precision_score(y_test, y_test_pred_proba)

# Plot the Precision-Recall Curve

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='blue', lw=2, label=f'Average Precision (AP) = {avg_precision:.2f}')
plt.fill_between(recall, precision, alpha=0.4, color='skyblue')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.title('Precision-Recall Curve')
plt.legend(loc="upper right")
plt.show()
